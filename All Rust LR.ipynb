# %%
#imports

import h5py
import numpy as np
from scipy import stats
from scipy.stats import zscore
from matplotlib import pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.patches as mpatches
import pickle
import re

import torch
import torch.nn as nn
import torch.nn.functional as F

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, explained_variance_score
from sklearn.linear_model import RidgeCV
from sklearn.decomposition import PCA

import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
# Set Recording Session, Model, sh_limit
year = '2024'
month = '04'
day = '03'

model_type = 'model'
layer = 'conv402'
sh_limit = .3

image_set = 'Nat305'

trials_included = 10000

# %%
# Load data

marm_avg_spikes_t = np.load(f'./{year}_{month}_{day}/marm_avg_spikes_{year}{month}{day}.npy')
marm_avg_spikes = zscore(np.transpose(marm_avg_spikes_t.astype('float32')), axis=1)[:trials_included]

marm_model_outputs_bad = np.load(f'./Model Outputs/marm_{model_type}_{layer}_outputs_{image_set}.npy')[:trials_included]
marm_model_outputs = zscore(marm_model_outputs_bad, axis=1)

print(marm_avg_spikes.shape)
print(marm_model_outputs.shape)
# Out:
# (3364, 384)
# (305, 25088)

# %%
# load and test neural

neural_tot = marm_avg_spikes
neural_dim = 384

print("neural min:", neural_tot.min())
print("neural max:", neural_tot.max())
print("neural mean:", neural_tot.mean())
print("neural std:", neural_tot.std())

neural_tot.shape
# Out:
# neural min: -1.4307736
# neural max: 12.396545
# neural mean: 9.124968e-10
# neural std: 0.9999998
# (3364, 384)

# %%
# load and test model outputs

model_tot = marm_model_outputs

print("outputs min:", model_tot.min())
print("outputs max:", model_tot.max())
print("outputs mean:", model_tot.mean())
print("outputs std:", model_tot.std())

model_tot.shape
# Out:
# outputs min: -10.164923
# outputs max: 9.61707
# outputs mean: 2.3530773e-09
# outputs std: 1.0000002
# (305, 25088)

# %%
# Subset of model outputs

model_outputs_dim = 300

rand_idx = np.arange(model_tot.shape[1])
np.random.shuffle(rand_idx)
subset_idx = rand_idx[:model_outputs_dim]

subset_outputs = model_tot[:, subset_idx]

subset_outputs.shape
# Out:
# (305, 300)

# %%
# make new indices for SHR
ch_tot = marm_avg_spikes.shape[1]
stim_tot = marm_avg_spikes.shape[0]
indices = np.arange(stim_tot)

# %%
year = '2024'

# %%
# load natimg_path_list

with open(f'./{year}_{month}_{day}/natimg_path_list_{year}{month}{day}', 'rb') as fp:   # Unpickling
    natimg_path_list = pickle.load(fp)

natimg_path_list = natimg_path_list[:trials_included]
len(natimg_path_list)
# Out:
# 3364

# %%
# get max_reps

trial_counts = []

for path in set(natimg_path_list):
    trial_counts.append(natimg_path_list.count(path))

max_reps = max(trial_counts)

print(max_reps)
# Out:
# 15

# %%
# Load data
tt7_marm_avg_spikes_t = np.load(f'./2027_{month}_{day}/marm_avg_spikes_2027{month}{day}.npy')
tt7_marm_avg_spikes = zscore(np.transpose(tt7_marm_avg_spikes_t.astype('float32')), axis=1)[:trials_included]

print(tt7_marm_avg_spikes.shape)
# Out:
# (3364, 384)

# %%
x = abs(tt7_marm_avg_spikes_t) - abs(marm_avg_spikes_t)
x.sum()
# Out:
# 2447.3607142857218

# %%
# load natimg_path_list
year = '2027'
with open(f'./{year}_{month}_{day}/natimg_path_list_{year}{month}{day}', 'rb') as fp:   # Unpickling
    tt7_natimg_path_list = pickle.load(fp)

tt7_natimg_path_list = tt7_natimg_path_list[:trials_included]
len(tt7_natimg_path_list)
# Out:
# 3364

# %%
natimg_path_list
# Out:
# ['/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_1.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_2.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_3.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_4.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_5.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_6.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_7.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_8.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_9.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_10.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_11.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_12.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_13.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_13.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_13.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_13.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_13.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_13.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_13.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_14.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_15.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_16.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_17.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_18.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_19.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_20.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_21.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_22.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_23.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_24.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_25.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_26.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_27.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_28.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_29.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_30.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_31.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_32.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_33.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_34.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_34.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_34.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_34.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_34.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_34.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_34.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_34.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_35.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_36.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_37.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_38.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_39.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_40.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_41.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_42.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_43.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_44.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_45.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_46.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_46.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_46.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_46.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_46.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_46.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_46.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_47.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_48.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_49.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_50.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_51.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_52.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_53.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_54.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_55.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_56.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_57.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_58.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_59.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_60.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_61.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_62.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_63.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_64.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_65.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_66.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_67.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_67.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_67.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_67.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_67.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_67.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_67.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_67.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_68.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_69.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_70.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_71.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_72.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_73.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_74.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_75.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_76.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_77.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_78.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_79.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_80.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_81.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_82.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_83.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_84.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_85.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_85.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_85.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_85.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_85.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_85.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_85.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_86.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_87.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_88.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_89.png',
#  '/Users/parsatalaie/Downloads/rust_natimgs/Nat300_89.png',
#  ...]

# %%
# Get demon matrix for each neuron

img_count = len(set(natimg_path_list))
sh_data = np.zeros(ch_tot)
img_spikes_tot = np.zeros((ch_tot, max_reps, img_count))

for ch in range(ch_tot):
    neuron = marm_avg_spikes[:, ch]
    count_arr = np.zeros((max_reps, img_count))
    count_arr[:] = np.nan
    for i in range(img_count):
        path = f'/Users/parsatalaie/Downloads/rust_natimgs/Nat300_{i+1}.png'
        idx_list = [i for i, j in enumerate(natimg_path_list) if j == path]
        for rep, idx in enumerate(idx_list):
            count_arr[rep, i] = neuron[idx]
    img_spikes_tot[ch] = count_arr
    neuron_1, neuron_2 = count_arr[::2], count_arr[1::2]
    neuron_1_avg = np.nanmean(neuron_1, axis=0)
    neuron_2_avg = np.nanmean(neuron_2, axis=0)
    sh, _ = stats.pearsonr(neuron_1_avg, neuron_2_avg)
    sh_data[ch] = sh

# %%
# Get good idx
good_idx = np.where(sh_data >= sh_limit)[0]

# get good sh, exp
good_sh = sh_data[good_idx]

good_ch_tot = good_idx.shape[0]

print(f'Number of good neurons: {good_ch_tot}')
# Out:
# Number of good neurons: 246

# %%
good_idx
# Out:
# array([  0,   1,   2,   4,   5,   6,   9,  10,  11,  13,  14,  17,  18,
#         19,  21,  22,  25,  26,  29,  30,  31,  33,  34,  37,  38,  39,
#         41,  42,  43,  44,  45,  46,  47,  49,  50,  52,  53,  55,  57,
#         58,  59,  60,  61,  62,  65,  66,  71,  72,  73,  74,  75,  76,
#         77,  80,  81,  85,  86,  89,  90,  93,  94,  95,  96,  97,  98,
#         99, 100, 102, 103, 104, 105, 106, 107, 108, 111, 112, 113, 114,
#        115, 120, 123, 124, 125, 127, 128, 129, 130, 131, 133, 138, 141,
#        142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154,
#        155, 156, 157, 158, 159, 160, 162, 163, 164, 166, 167, 168, 169,
#        170, 171, 172, 175, 177, 178, 179, 180, 182, 183, 184, 185, 186,
#        189, 190, 191, 193, 194, 195, 196, 197, 198, 199, 200, 202, 203,
#        204, 205, 206, 207, 209, 210, 212, 213, 214, 215, 217, 218, 221,
#        222, 223, 225, 226, 227, 228, 229, 230, 232, 233, 234, 235, 236,
#        237, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250,
#        251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263,
#        264, 265, 266, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277,
#        279, 280, 281, 284, 285, 286, 287, 288, 289, 290, 291, 292, 295,
#        296, 297, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309,
#        310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322,
#        323, 324, 327, 328, 330, 332, 333, 334, 335, 336, 337, 341, 342,
#        344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 356, 357,
#        358, 359, 360, 361, 362, 363, 364, 365, 367, 368, 369, 370, 371,
#        372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383])

# %%
# Create indices
folds = 3
indices = np.arange(stim_tot)

indices_list = []
for i in range(folds):
    train_indices, test_indices = train_test_split(indices, test_size = .2)
    train_indices = np.sort(train_indices)
    test_indices = np.sort(test_indices)
    indices_set = [train_indices, test_indices]
    indices_list.append(indices_set)

#test_indices = np.load('/Users/parsatalaie/Desktop/Marmoset Data Analysis/marm_even_test_trial_idx.npy').astype(int)
#train_indices = np.delete(n_train_indices, test_indices)

# %%
# prepare for loop cv

scores_tot = np.zeros((folds, good_ch_tot))
alphas_tot = np.zeros((folds, good_ch_tot))
exp_data_tot = np.zeros((folds, good_ch_tot))
corr_data_tot = np.zeros((folds, good_ch_tot))
lr_outputs_np_tot = np.zeros((folds, indices_list[0][1].shape[0], good_ch_tot))
print(lr_outputs_np_tot.shape)
# Out:
# (3, 673, 16)

# %%
# Check for number of components
for i in range(50, model_tot.shape[1]//2, 50):
    pca = PCA(n_components = i)
    pca.fit(model_tot)
    print(f'{i} : {pca.explained_variance_ratio_.sum() * 100:.4f}')
    if pca.explained_variance_ratio_.sum() >= 1:
        break
# Out:
# 50 : 37.0365
# 100 : 55.7222
# 150 : 70.2991
# 200 : 82.1368
# 250 : 92.3872
# 300 : 100.0000

# %%
# Set components
num_comps = 300

pca = PCA(n_components = num_comps)
pca_outputs = pca.fit_transform(model_tot)
pca.explained_variance_ratio_.sum()
# Out:
# 1.0

# %%
# Get a model_tot who has aligned trials with neural stims

def extract_integers_before_png(string):
    # Pattern to match one or more digits (\d+) followed by .png
    pattern = r"(\d+)\.png$"
    
    # Search for the pattern in the string
    match = re.search(pattern, string)
    
    # If a match is found, return the digits
    if match:
        return match.group(1)
    else:
        return None

# Get empty matrix
model_tot = np.zeros((stim_tot, num_comps))

for stim in range(stim_tot):
    # Get the image number from the path
    image_number = int(extract_integers_before_png(natimg_path_list[stim]))

    # Subtract 1 to convert it to idx that can be applied on model outputs
    image_idx = image_number-1

    # Apply it to model_matrix
    model_tot[stim] = pca_outputs[image_idx, :]

# %%
# do stupid fix (make this better later)
pca_outputs = model_tot

# %%
# for loop regression
'''
alphas_list = [.01, .02, .05, .1, .5, 1, 5, 10, 50, 100, 500, 1000, 2500, 5000,
               10000, 25000, 50000, 100000, 500000]
'''
alphas_list = [.01, .02, .05, .1, .5, 1, 5, 10]


for fold, tt_idx in enumerate(indices_list):
    train_indices, test_indices = tt_idx[0], tt_idx[1]
    
    predictions = np.zeros((test_indices.shape[0], good_ch_tot))
    scores = np.zeros(good_ch_tot)
    alphas = np.zeros(good_ch_tot)
    
    for i in range(good_ch_tot):
        neuron = marm_avg_spikes[:, good_idx[i]]
        model = RidgeCV(alphas=alphas_list).fit(pca_outputs[train_indices], neuron[train_indices])
        synth_neuron = model.predict(pca_outputs[test_indices])
        predictions[:, i] = synth_neuron
        scores[i] = model.score(pca_outputs[train_indices], neuron[train_indices])
        alphas[i] = model.alpha_

    lr_outputs_np_tot[fold] = predictions

    # Check scores
    scores_tot[fold] = scores

    # Check alphas
    alphas_tot[fold] = alphas
    
    for i in range(good_ch_tot):
        neuron = marm_avg_spikes[:, good_idx[i]]
        y = r2_score(neuron[test_indices], predictions[:, i])
        z, _ = stats.pearsonr(neuron[test_indices], predictions[:, i])
        exp_data_tot[fold, i] = y
        corr_data_tot[fold, i] = z
    
    # Individual Explained Variance
    exp_var = r2_score(marm_avg_spikes[test_indices, :][:, good_idx], predictions)
    print(f"Explained Variance of the model: {100*exp_var:.2f}%")
# Out:
# Explained Variance of the model: -9.30%
# Explained Variance of the model: -10.01%
# Explained Variance of the model: -9.36%

# %%
# Check alphas

for i in alphas_list:
    print(f'{i} : {np.where(alphas_tot == i)[0].shape[0]}')
# Out:
# 0.01 : 0
# 0.02 : 0
# 0.05 : 0
# 0.1 : 0
# 0.5 : 0
# 1 : 0
# 5 : 0
# 10 : 48

# %%
# Get good_exp, good_corr

good_exp = exp_data_tot.mean(axis = 0)
good_corr = corr_data_tot.mean(axis = 0)
good_corr.shape
# Out:
# (16,)

# %%
# Set metric, model_title

eval = 'r'

if eval == 'r':
    metric = good_corr
    y_label = 'Correlation of model output, neuron'
    title = 'Correlation vs. SHR'
    eval_scores = np.sqrt(scores_tot)
elif eval == 'R^2':
    metric = good_exp
    y_label = 'Explained Variance by model'
    title = 'ExpVar vs. SHR'
    eval_scores = scores_tot

if model_type == 'model':
    model_title = f'Trained ResNet50 ({layer})'
elif model_type == 'rand':
    model_title = f'Untrained ResNet50 ({layer})'
elif model_type == 'barlow':
    model_title = f'Trained Barlow ResNet50 ({layer})'
elif model_type == 'model34':
    model_title = f'Trained ResNet34 ({layer})'
elif model_type == 'model18':
    model_title = f'Trained ResNet18 ({layer})'

print(eval)
# Out:
# r

# %%
# Create histogram for SHR
set_bins = np.arange(21)*.05
plt.hist(good_sh, bins = set_bins, edgecolor = 'black', alpha = .8)
plt.hist(good_corr, bins = set_bins, edgecolor = 'red', alpha = .5)
plt.title(f'{title} ({model_title})')
plt.xlabel(f'SHR (blue) and {eval}(model, neuron) (orange)')
plt.show()

# %%
# Create plot

# Colors
ch_depth = np.load(f'./{year}_{month}_{day}/ch_depth_{year}{month}{day}.npy')

# Plot
scatter = plt.scatter(
    good_sh, metric, c = ch_depth[good_idx], cmap = 'hot')
plt.title(f'{title} ({year}/{month}/{day} , {model_title}, Rust)')
plt.ylabel(y_label)
plt.xlabel('SH-Reliability of Neuron')

#colorbar
cbar = plt.colorbar(scatter)
cbar.set_label('Depth')

# Additional
plt.axline((0, 0), slope=1, c='k')
scatter = plt.scatter(
    good_sh, eval_scores.mean(axis=0), c = 'm')
r_patch = mpatches.Patch(color='red', label = 'Test scores')
m_patch = mpatches.Patch(color='magenta', label = 'Training scores')
plt.legend(handles = [r_patch, m_patch], loc = "upper left")

# Set X-axis
ax = plt.gca()
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])

# Show the plot
plt.show()

# Print line of best fit, pearsonr
r, p = stats.pearsonr(good_sh, metric)
print(f'Pearson Correlation: {r:.4f}')
print(f'Avg Split-Halves Reliability: {good_sh.mean():.4f}')
print(f'Avg {eval}: {metric.mean():.4f}')

relative_exp = metric / (2 * good_sh / (1 + good_sh))

print(f'Avg Relative {eval}: {relative_exp.mean():.4f}')

neg_pct = metric[metric < 0].shape[0]/metric.shape[0]

print(f'Neurons with negative {eval}: {neg_pct*100:.2f}%')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 4
#       1 # Create plot
#       2
#       3 # Colors
# ----> 4 ch_depth = np.load(f'./{year}_{month}_{day}/ch_depth_{year}{month}{day}.npy')
#       6 # Plot
#       7 scatter = plt.scatter(
#       8     good_sh, metric, c = ch_depth[good_idx], cmap = 'hot')
#
# File /opt/anaconda3/lib/python3.12/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './2027_04_03/ch_depth_20270403.npy'

# %%
# Aggregate all responses, linreg into one dict
resp_dict = {'IT Data': neural_tot[:, good_idx][indices_list[0][1]], 'Model Output': lr_outputs_np_tot[0]}

resp_dict['IT Data'].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 # Aggregate all responses, linreg into one dict
# ----> 2 resp_dict = {'IT Data': neural_tot[:, good_idx][indices_list[0][1]], 'Model Output': lr_outputs_np_tot[0]}
#       4 resp_dict['IT Data'].shape
#
# NameError: name 'indices_list' is not defined

# %%
# Aggregate all responses, linreg into one dict
resp_dict = {'IT Data': neural_tot, 'Model Output': model_tot}

resp_dict['Model Output'].shape
# Out:
# (2970, 300)

# %%
neural_tot.shape
# Out:
# (2970, 384)

# %%
model_tot.shape
# Out:
# (2970, 300)

# %%
# Plotting Functions

def show_stimulus(img, ax=None, show=False):
  """Visualize a stimulus"""
  if ax is None:
    ax = plt.gca()
  ax.imshow(img, cmap=mpl.cm.binary)
  ax.set_aspect('auto')
  ax.set_xticks([])
  ax.set_yticks([])
  ax.spines['left'].set_visible(False)
  ax.spines['bottom'].set_visible(False)
  if show:
    plt.show()


def plot_corr_matrix(rdm, ax=None, show=False):
  """Plot dissimilarity matrix

  Args:
    rdm (numpy array): n_stimuli x n_stimuli representational dissimilarity
      matrix
    ax (matplotlib axes): axes onto which to plot

  Returns:
    nothing

  """
  if ax is None:
    ax = plt.gca()
  image = ax.imshow(rdm, vmin=0.0, vmax=2.0)
  ax.set_xticks([])
  ax.set_yticks([])
  cbar = plt.colorbar(image, ax=ax, label='dissimilarity')
  if show:
    plt.show()


def plot_multiple_rdm(rdm_dict):
  """Draw multiple subplots for each RDM in rdm_dict."""
  fig, axs = plt.subplots(1, len(rdm_dict),
                          figsize=(4 * len(resp_dict), 3.5))

  # Compute RDM's for each set of responses and plot
  for i, (label, rdm) in enumerate(rdm_dict.items()):

    image = plot_corr_matrix(rdm, axs[i])
    axs[i].set_title(label)
  plt.show()


def plot_rdm_rdm_correlations(rdm_sim):
  """Draw a bar plot showing between-RDM correlations."""
  f, ax = plt.subplots()
  ax.bar(rdm_sim.keys(), rdm_sim.values())
  ax.set_xlabel('Deep network model layer')
  ax.set_ylabel('Correlation of model layer RDM\nwith IT Data')
  plt.show()


def plot_rdm_rows(ori_list, rdm_dict, rdm_oris):
  """Plot the dissimilarity of response to each stimulus with response to one
  specific stimulus

  Args:
    ori_list (list of float): plot dissimilarity with response to stimulus with
      orientations closest to each value in this list
    rdm_dict (dict): RDM's from which to extract dissimilarities
    rdm_oris (np.ndarray): orientations corresponding to each row/column of RDMs
    in rdm_dict

  """
  n_col = len(ori_list)
  f, axs = plt.subplots(1, n_col, figsize=(4 * n_col, 4), sharey=True)

  # Get index of orientation closest to ori_plot
  for ax, ori_plot in zip(axs, ori_list):
    iori = np.argmin(np.abs(rdm_oris - ori_plot))

    # Plot dissimilarity curves in each RDM
    for label, rdm in rdm_dict.items():
      ax.plot(rdm_oris, rdm[iori, :], label=label)

    # Draw vertical line at stimulus we are plotting dissimilarity w.r.t.
    ax.axvline(rdm_oris[iori], color=".7", zorder=-1)

    # Label axes
    ax.set_title(f'Dissimilarity with response\nto {ori_plot: .0f}$^o$ stimulus')
    ax.set_xlabel('Stimulus orientation ($^o$)')

  axs[0].set_ylabel('Dissimilarity')
  axs[-1].legend(loc="upper left", bbox_to_anchor=(1, 1))
  plt.tight_layout()
  plt.show()

# %%
# Define correlate_rdms
def correlate_rdms(rdm1, rdm2):
    """Correlate off-diagonal elements of two RDM's
  
    Args:
      rdm1 (np.ndarray): S x S representational dissimilarity matrix
      rdm2 (np.ndarray): S x S representational dissimilarity matrix to
        correlate with rdm1
  
    Returns:
      float: correlation coefficient between the off-diagonal elements
        of rdm1 and rdm2
  
    """
  
    # Extract off-diagonal elements of each RDM
    ioffdiag = np.triu_indices(rdm1.shape[0], k=1)  # indices of off-diagonal elements
    rdm1_offdiag = rdm1[ioffdiag]
    rdm2_offdiag = rdm2[ioffdiag]
  
    corr_coef = np.corrcoef(rdm1_offdiag, rdm2_offdiag)[0,1]
  
    return corr_coef

# %%
# RDM def and plot

def RDM(resp):
    """Compute the representational dissimilarity matrix (RDM)
  
    Args:
      resp (ndarray): S x N matrix with population responses to
        each stimulus in each row
  
    Returns:
      ndarray: S x S representational dissimilarity matrix
    """
  
    # z-score responses to each stimulus
    zresp = resp #zscore(resp, axis=1)
  
    # Compute RDM
    RDM = 1 - (zresp @ zresp.T) / zresp.shape[1]
    return RDM


# Compute RDMs for each layer
rdm_dict = {label: RDM(resp) for label, resp in resp_dict.items()}

# Plot RDMs
plot_multiple_rdm(rdm_dict)

# Correlate RDMs

# Split RDMs into V1 responses and model responses
rdm_model = rdm_dict.copy()
rdm_IT = rdm_model.pop('IT Data')

# Correlate off-diagonal terms of dissimilarity matrices
rdm_sim = {label: correlate_rdms(rdm_IT, rdm) for label, rdm in rdm_model.items()}

print(f'RDM correlation: {rdm_sim['Model Output']}')
# Out:
# RDM correlation: -0.0028662358806397477

# %%
# Get demon matrix for each model output feature
img_model_tot = np.zeros((model_outputs_dim, max_reps, img_count))

for ch in range(model_outputs_dim):
    neuron = subset_outputs[:, ch]
    count_arr = np.zeros((max_reps, img_count))
    count_arr[:] = np.nan
    for i in range(img_count):
        path = f'/Users/parsatalaie/Downloads/rust_natimgs/Nat300_{i+1}.png'
        idx_list = [i for i, j in enumerate(natimg_path_list) if j == path]
        for rep, idx in enumerate(idx_list):
            count_arr[rep, i] = neuron[idx]
    img_model_tot[ch] = count_arr

# %%
# Garbage Adam LR
class LinearRegression(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(input_dim, output_dim)
    
    def forward(self, x):
        return self.linear(x)

input_dim = model_outputs_dim       # takes variable 'x' 
output_dim = neural_dim       # takes variable 'y'
learning_rate = 0.01 
epochs = 1000

linreg = LinearRegression(input_dim, output_dim)  # n input features
criterion = nn.MSELoss()
optimizer = optim.Adam(linreg.parameters(), lr=learning_rate, weight_decay=0)

inputs = subset_outputs
labels = neural_tot

for epoch in range(epochs):
    # Converting inputs and labels to Variable

    # Clear gradient buffers because we don't want any gradient from previous epoch to carry forward, dont want to cummulate gradients
    optimizer.zero_grad()

    # get output from the model, given the inputs
    outputs = linreg(inputs)

    # get loss for the predicted output
    loss = criterion(outputs, labels)
    # get gradients w.r.t to parameters
    loss.backward()

    # update parameters
    optimizer.step()

    #print('epoch {}, loss {}'.format(epoch, loss.item()))

# Create og lr_outputs_np

lr_outputs = linreg(subset_outputs)
lr_outputs_np = lr_outputs.detach().cpu().numpy()
